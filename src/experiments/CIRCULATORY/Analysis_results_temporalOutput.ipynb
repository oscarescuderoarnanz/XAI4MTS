# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bootstrap

# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from itertools import combinations

def bootstrap_auc_diff(y_true, scores_a, scores_b,
                       n_iterations=2000, ci=95, seed=0):
    rng = np.random.default_rng(seed)
    diffs = np.empty(n_iterations)
    n = 1000
    for i in range(n_iterations):
        idx = rng.choice(n, size=n, replace=True)
        a = roc_auc_score(y_true[idx], scores_a[idx])
        b = roc_auc_score(y_true[idx], scores_b[idx])
        diffs[i] = a - b
    mean_diff = diffs.mean()
    lower = np.percentile(diffs, (100 - ci) / 2)
    upper = np.percentile(diffs, 100 - (100 - ci) / 2)
    p_value = np.mean(np.abs(diffs) >= abs(mean_diff))
    return mean_diff, (lower, upper), p_value, diffs

def compare_all_pairs(y_true, scores, n_iterations=2000, ci=95):
    records = []
    for m1, m2 in combinations(scores.keys(), 2):
        mean_diff, (low, high), p, diffs = bootstrap_auc_diff(
            y_true, scores[m1], scores[m2],
            n_iterations=n_iterations, ci=ci
        )
        records.append({
            'Model A': m1,
            'Model B': m2,
            'Mean ΔAUC': mean_diff,
            f'{ci}% CI': f'{low:.3f}, {high:.3f}',
            'p-value': p
        })
    return pd.DataFrame(records).sort_values('p-value').reset_index(drop=True)

n_steps = 8
y_true_pattern = "../../../DATA/CIRCULATORY/s{split}/y_test_tensor_robustNorm.csv"
pkl_paths = {
    "GRU":           "POST-HOC/Results_GRU/split_1/y_pred_split_1.pkl",
    "LSTM":          "POST-HOC/Results_LSTM/split_1/y_pred_split_1.pkl",
    "Vanilla RNN":   "POST-HOC/Results_Vanilla/split_1/y_pred_split_1.pkl",
    "GRU Had. Att.":"INTRINSIC/Results_GRU_Had/split_1/y_pred_split_1.pkl",
    "LSTM Had. Att.":"INTRINSIC/Results_LSTM_Had/split_1/y_pred_split_1.pkl",
    "Vanilla RNN Had. Att.":"INTRINSIC/Results_Vanilla_Had/split_1/y_pred_split_1.pkl",
    "Transformer":   "POST-HOC/Results_transformer/split_1/y_pred_split_1.pkl",
    "Transformer Had. Att.":"INTRINSIC/Results_transformer_Had/split_1/y_pred_split_1.pkl",
}

y_list = []
scores_acc = {m: [] for m in pkl_paths}

for split in [1, 2, 3]:
    df = pd.read_csv(y_true_pattern.format(split=split))
    flat_true = df['individualMRGerm'].values  
    mask = (flat_true != 666)
    y_list.append(flat_true[mask].astype(int))
    
    for m, tmpl in pkl_paths.items():
        pfile = (tmpl.replace("split_1", f"split_{split}").replace("_1.pkl", f"_{split}.pkl"))
        
        print(pfile)
        pred_seq = pickle.load(open(pfile, "rb"))
        arr = np.asarray(pred_seq)
        flat = arr.reshape(-1, arr.shape[-1])  

        max_t = flat.max(axis=1)         
        scores_acc[m].append(max_t[mask])

y_all = np.concatenate(y_list)
scores_all = {m: np.concatenate(lst) for m, lst in scores_acc.items()}

print(y_all.shape)
df_results = compare_all_pairs(y_all, scores_all,
                               n_iterations=2000, ci=95)

print(df_results.to_string(index=False))
# Out:
# POST-HOC/Results_GRU/split_1/y_pred_split_1.pkl
# POST-HOC/Results_LSTM/split_1/y_pred_split_1.pkl
# POST-HOC/Results_Vanilla/split_1/y_pred_split_1.pkl
# INTRINSIC/Results_GRU_Had/split_1/y_pred_split_1.pkl
# INTRINSIC/Results_LSTM_Had/split_1/y_pred_split_1.pkl
# INTRINSIC/Results_Vanilla_Had/split_1/y_pred_split_1.pkl
# POST-HOC/Results_transformer/split_1/y_pred_split_1.pkl
# INTRINSIC/Results_transformer_Had/split_1/y_pred_split_1.pkl
# POST-HOC/Results_GRU/split_2/y_pred_split_2.pkl
# POST-HOC/Results_LSTM/split_2/y_pred_split_2.pkl
# POST-HOC/Results_Vanilla/split_2/y_pred_split_2.pkl
# INTRINSIC/Results_GRU_Had/split_2/y_pred_split_2.pkl
# INTRINSIC/Results_LSTM_Had/split_2/y_pred_split_2.pkl
# INTRINSIC/Results_Vanilla_Had/split_2/y_pred_split_2.pkl
# POST-HOC/Results_transformer/split_2/y_pred_split_2.pkl
# INTRINSIC/Results_transformer_Had/split_2/y_pred_split_2.pkl
# POST-HOC/Results_GRU/split_3/y_pred_split_3.pkl
# POST-HOC/Results_LSTM/split_3/y_pred_split_3.pkl
# POST-HOC/Results_Vanilla/split_3/y_pred_split_3.pkl
# INTRINSIC/Results_GRU_Had/split_3/y_pred_split_3.pkl
# INTRINSIC/Results_LSTM_Had/split_3/y_pred_split_3.pkl
# INTRINSIC/Results_Vanilla_Had/split_3/y_pred_split_3.pkl
# POST-HOC/Results_transformer/split_3/y_pred_split_3.pkl
# INTRINSIC/Results_transformer_Had/split_3/y_pred_split_3.pkl
# (21126,)
#               Model A               Model B  Mean ΔAUC         95% CI  p-value
#        LSTM Had. Att. Vanilla RNN Had. Att.   0.001509   0.001, 0.002    0.473
#           Vanilla RNN Vanilla RNN Had. Att.  -0.006195 -0.007, -0.005    0.483
#                  LSTM Vanilla RNN Had. Att.  -0.003924 -0.005, -0.003    0.483
#                   GRU Vanilla RNN Had. Att.  -0.005549 -0.007, -0.005    0.485
#                  LSTM        LSTM Had. Att.  -0.005433 -0.006, -0.005    0.485
#         GRU Had. Att.        LSTM Had. Att.  -0.000312 -0.001, -0.000    0.486
#                  LSTM           Vanilla RNN   0.002271   0.001, 0.003    0.486
#                   GRU                  LSTM  -0.001625 -0.003, -0.001    0.488
#        LSTM Had. Att. Transformer Had. Att.   0.001324   0.001, 0.002    0.488
#                   GRU        LSTM Had. Att.  -0.007058 -0.008, -0.006    0.488
#           Vanilla RNN        LSTM Had. Att.  -0.007705 -0.009, -0.007    0.488
#                  LSTM Transformer Had. Att.  -0.004110 -0.005, -0.003    0.490
#                  LSTM         GRU Had. Att.  -0.005121 -0.006, -0.004    0.491
#           Vanilla RNN         GRU Had. Att.  -0.007393 -0.008, -0.006    0.493
#                   GRU Transformer Had. Att.  -0.005734 -0.007, -0.005    0.495
#                  LSTM           Transformer  -0.004343 -0.005, -0.004    0.496
#        LSTM Had. Att.           Transformer   0.001090   0.001, 0.001    0.497
#           Vanilla RNN           Transformer  -0.006614 -0.007, -0.006    0.500
#           Vanilla RNN Transformer Had. Att.  -0.006381 -0.007, -0.005    0.500
#                   GRU           Vanilla RNN   0.000646  -0.000, 0.001    0.502
#         GRU Had. Att. Transformer Had. Att.   0.001012   0.000, 0.002    0.503
#         GRU Had. Att.           Transformer   0.000778   0.000, 0.001    0.505
#                   GRU           Transformer  -0.005968 -0.007, -0.005    0.506
#         GRU Had. Att. Vanilla RNN Had. Att.   0.001197   0.001, 0.002    0.508
#                   GRU         GRU Had. Att.  -0.006746 -0.008, -0.006    0.510
# Vanilla RNN Had. Att.           Transformer  -0.000419  -0.001, 0.000    0.515
#           Transformer Transformer Had. Att.   0.000234  -0.000, 0.001    0.553
# Vanilla RNN Had. Att. Transformer Had. Att.  -0.000185  -0.001, 0.000    0.626

# %%
labels = []
means  = []
lows   = []
highs  = []
sig    = []  

diffs_dict = {}
for m1, m2 in combinations(scores_all.keys(), 2):
    mean_diff, (low, high), p, diffs = bootstrap_auc_diff(
        y_all, scores_all[m1], scores_all[m2],
        n_iterations=2000, ci=95, seed=42
    )
    label = f"{m1} – {m2}"
    labels.append(label)
    means.append(mean_diff)
    lows.append(mean_diff - low)   
    highs.append(high - mean_diff)  
    sig.append((low > 0) or (high < 0))
    diffs_dict[label] = diffs

# %%
fig, ax = plt.subplots(figsize=(6, len(labels)*0.4))
y_pos = np.arange(len(labels))

ax.errorbar(means, y_pos, xerr=[lows, highs],
            fmt='o',  
            markersize=5,
            capsize=3)
for i, s in enumerate(sig):
    if s:
        ax.plot(means[i], y_pos[i], marker='D', markersize=6)  
    else:
        ax.plot(means[i], y_pos[i], marker='o', markersize=6, alpha=0.5)

ax.axvline(0, linestyle='--')         
ax.set_yticks(y_pos)
ax.set_yticklabels(labels)
plt.tight_layout()
plt.savefig('./Figures/forest_plot_CIRC.pdf')
plt.show()

# %%
paths = {
    'GRU':                     "POST-HOC/Results_GRU/metrics_GRU.csv",
    'LSTM':                    "POST-HOC/Results_LSTM/metrics_LSTM.csv",
    'Vanilla RNN':             "POST-HOC/Results_Vanilla/metrics_Vanilla.csv",
    'GRU Had. Att.':           "INTRINSIC/Results_GRU_Had/metrics_GRU_Had.csv",
    'LSTM Had. Att.':          "INTRINSIC/Results_LSTM_Had/metrics_LSTM_Had.csv",
    'Vanilla RNN Had. Att.':   "INTRINSIC/Results_Vanilla_Had/metrics_Vanilla_Had.csv",
    'Transformer':             "POST-HOC/Results_transformer/metrics_transformer.csv",
    'Transformer Had. Att.':   "INTRINSIC/Results_transformer_Had/metrics_transformer_Had.csv",
}

roc = {}
n_splits = 3
n_horizons = 8

for model, path in paths.items():
    df = pd.read_csv(path)
    if 'Time Step' in df.columns:
        df = df.sort_values('Time Step').reset_index(drop=True)
    arr = df['ROC AUC'].values
    assert arr.size == n_splits * n_horizons, \
        f"{model}: esperado {n_splits*n_horizons} valores, hay {arr.size}"
    roc[model] = arr.reshape(n_splits, n_horizons)

# %% [markdown]
# ## 2Permutation

# %%
import numpy as np
import itertools
import pandas as pd

def exhaustive_count_mean(D, two_sided=True, n_iters=4):
    n_splits = D.shape[0]
    t_obs = D.ravel().mean()
    count = 0
    total = 0

    for signs in itertools.product([-1, 1], repeat=n_splits):
        if total >= n_iters:
            break
        signs = np.array(signs)
        t_s = (D * signs[:, None]).mean()
        if two_sided:
            if abs(t_s) >= abs(t_obs):
                count += 1
        else:
            if t_s >= t_obs:
                count += 1
        total += 1

    return t_obs, count, total


results = []
for A, B in itertools.combinations(roc.keys(), 2):
    D = roc[A] - roc[B]

    t_m, cnt_m, tot_m = exhaustive_count_mean(D, two_sided=False, n_iters=8)
    p_m = (cnt_m + 1) / (tot_m + 1)

    results.append({
        'Model A': A,
        'Model B': B,
        'T_obs_mean': t_m,
        'Count_mean': cnt_m,
        'Total_mean': tot_m,
        'P_one_sided_mean': p_m
    })

res_df = pd.DataFrame(results)
print(res_df)
# Out:
#                   Model A                Model B  T_obs_mean  Count_mean  \
# 0                     GRU                   LSTM   -0.001673           8
# 1                     GRU            Vanilla RNN    0.000565           2
# 2                     GRU          GRU Had. Att.   -0.007089           8
# 3                     GRU         LSTM Had. Att.   -0.007203           8
# 4                     GRU  Vanilla RNN Had. Att.   -0.005646           8
# 5                     GRU            Transformer   -0.005504           8
# 6                     GRU  Transformer Had. Att.   -0.005764           8
# 7                    LSTM            Vanilla RNN    0.002238           1
# 8                    LSTM          GRU Had. Att.   -0.005416           8
# 9                    LSTM         LSTM Had. Att.   -0.005530           8
# 10                   LSTM  Vanilla RNN Had. Att.   -0.003973           8
# 11                   LSTM            Transformer   -0.003831           8
# 12                   LSTM  Transformer Had. Att.   -0.004091           8
# 13            Vanilla RNN          GRU Had. Att.   -0.007653           8
# 14            Vanilla RNN         LSTM Had. Att.   -0.007767           8
# 15            Vanilla RNN  Vanilla RNN Had. Att.   -0.006211           8
# 16            Vanilla RNN            Transformer   -0.006069           8
# 17            Vanilla RNN  Transformer Had. Att.   -0.006329           8
# 18          GRU Had. Att.         LSTM Had. Att.   -0.000114           7
# 19          GRU Had. Att.  Vanilla RNN Had. Att.    0.001442           1
# 20          GRU Had. Att.            Transformer    0.001585           1
# 21          GRU Had. Att.  Transformer Had. Att.    0.001325           1
# 22         LSTM Had. Att.  Vanilla RNN Had. Att.    0.001556           1
# 23         LSTM Had. Att.            Transformer    0.001699           1
# 24         LSTM Had. Att.  Transformer Had. Att.    0.001438           1
# 25  Vanilla RNN Had. Att.            Transformer    0.000142           4
# 26  Vanilla RNN Had. Att.  Transformer Had. Att.   -0.000118           5
# 27            Transformer  Transformer Had. Att.   -0.000260           6
#
#     Total_mean  P_one_sided_mean
# 0            8          1.000000
# 1            8          0.333333
# 2            8          1.000000
# 3            8          1.000000
# 4            8          1.000000
# 5            8          1.000000
# 6            8          1.000000
# 7            8          0.222222
# 8            8          1.000000
# 9            8          1.000000
# 10           8          1.000000
# 11           8          1.000000
# 12           8          1.000000
# 13           8          1.000000
# 14           8          1.000000
# 15           8          1.000000
# 16           8          1.000000
# 17           8          1.000000
# 18           8          0.888889
# 19           8          0.222222
# 20           8          0.222222
# 21           8          0.222222
# 22           8          0.222222
# 23           8          0.222222
# 24           8          0.222222
# 25           8          0.555556
# 26           8          0.666667
# 27           8          0.777778

# %%
import numpy as np
import itertools
import pandas as pd

results_subsets = []
models = list(roc.keys())

for A in models:
    others = [m for m in models if m != A]
    for r in range(1, len(others)+1):
        for subset in itertools.combinations(others, r):
            arrs = [roc[m] for m in subset]
            mean_subset = np.mean(np.stack(arrs, axis=0), axis=0)
            
            D = roc[A] - mean_subset

            t_m, cnt_m, tot_m = exhaustive_count_mean(D, two_sided=False, n_iters=8)
            p_m = (cnt_m + 1) / (tot_m + 1)

            results_subsets.append({
                'Model A': A,
                'Subset': "+".join(subset),
                'Size': len(subset),
                'Count_mean': cnt_m,
                'Total_mean': tot_m,
                'T_obs_mean': t_m,
                'P_one_sided_mean': p_m
            })

df_subsets = pd.DataFrame(results_subsets)
df_subsets = df_subsets.sort_values(['Model A','Size','P_one_sided_mean']).reset_index(drop=True)

print(df_subsets.to_string(index=False))
# Out:
#               Model A                                                                                                Subset  Size  Count_mean  Total_mean  T_obs_mean  P_one_sided_mean
#                   GRU                                                                                           Vanilla RNN     1           2           8    0.000565          0.333333
#                   GRU                                                                                                  LSTM     1           8           8   -0.001673          1.000000
#                   GRU                                                                                         GRU Had. Att.     1           8           8   -0.007089          1.000000
#                   GRU                                                                                        LSTM Had. Att.     1           8           8   -0.007203          1.000000
#                   GRU                                                                                 Vanilla RNN Had. Att.     1           8           8   -0.005646          1.000000
#                   GRU                                                                                           Transformer     1           8           8   -0.005504          1.000000
#                   GRU                                                                                 Transformer Had. Att.     1           8           8   -0.005764          1.000000
#                   GRU                                                                                      LSTM+Vanilla RNN     2           7           8   -0.000554          0.888889
#                   GRU                                                                                    LSTM+GRU Had. Att.     2           8           8   -0.004381          1.000000
#                   GRU                                                                                   LSTM+LSTM Had. Att.     2           8           8   -0.004438          1.000000
#                   GRU                                                                            LSTM+Vanilla RNN Had. Att.     2           8           8   -0.003660          1.000000
#                   GRU                                                                                      LSTM+Transformer     2           8           8   -0.003589          1.000000
#                   GRU                                                                            LSTM+Transformer Had. Att.     2           8           8   -0.003719          1.000000
#                   GRU                                                                             Vanilla RNN+GRU Had. Att.     2           8           8   -0.003262          1.000000
#                   GRU                                                                            Vanilla RNN+LSTM Had. Att.     2           8           8   -0.003319          1.000000
#                   GRU                                                                     Vanilla RNN+Vanilla RNN Had. Att.     2           8           8   -0.002541          1.000000
#                   GRU                                                                               Vanilla RNN+Transformer     2           8           8   -0.002470          1.000000
#                   GRU                                                                     Vanilla RNN+Transformer Had. Att.     2           8           8   -0.002600          1.000000
#                   GRU                                                                          GRU Had. Att.+LSTM Had. Att.     2           8           8   -0.007146          1.000000
#                   GRU                                                                   GRU Had. Att.+Vanilla RNN Had. Att.     2           8           8   -0.006368          1.000000
#                   GRU                                                                             GRU Had. Att.+Transformer     2           8           8   -0.006296          1.000000
#                   GRU                                                                   GRU Had. Att.+Transformer Had. Att.     2           8           8   -0.006427          1.000000
#                   GRU                                                                  LSTM Had. Att.+Vanilla RNN Had. Att.     2           8           8   -0.006425          1.000000
#                   GRU                                                                            LSTM Had. Att.+Transformer     2           8           8   -0.006353          1.000000
#                   GRU                                                                  LSTM Had. Att.+Transformer Had. Att.     2           8           8   -0.006483          1.000000
#                   GRU                                                                     Vanilla RNN Had. Att.+Transformer     2           8           8   -0.005575          1.000000
#                   GRU                                                           Vanilla RNN Had. Att.+Transformer Had. Att.     2           8           8   -0.005705          1.000000
#                   GRU                                                                     Transformer+Transformer Had. Att.     2           8           8   -0.005634          1.000000
#                   GRU                                                                        LSTM+Vanilla RNN+GRU Had. Att.     3           8           8   -0.002732          1.000000
#                   GRU                                                                       LSTM+Vanilla RNN+LSTM Had. Att.     3           8           8   -0.002770          1.000000
#                   GRU                                                                LSTM+Vanilla RNN+Vanilla RNN Had. Att.     3           8           8   -0.002252          1.000000
#                   GRU                                                                          LSTM+Vanilla RNN+Transformer     3           8           8   -0.002204          1.000000
#                   GRU                                                                LSTM+Vanilla RNN+Transformer Had. Att.     3           8           8   -0.002291          1.000000
#                   GRU                                                                     LSTM+GRU Had. Att.+LSTM Had. Att.     3           8           8   -0.005321          1.000000
#                   GRU                                                              LSTM+GRU Had. Att.+Vanilla RNN Had. Att.     3           8           8   -0.004803          1.000000
#                   GRU                                                                        LSTM+GRU Had. Att.+Transformer     3           8           8   -0.004755          1.000000
#                   GRU                                                              LSTM+GRU Had. Att.+Transformer Had. Att.     3           8           8   -0.004842          1.000000
#                   GRU                                                             LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.     3           8           8   -0.004841          1.000000
#                   GRU                                                                       LSTM+LSTM Had. Att.+Transformer     3           8           8   -0.004793          1.000000
#                   GRU                                                             LSTM+LSTM Had. Att.+Transformer Had. Att.     3           8           8   -0.004880          1.000000
#                   GRU                                                                LSTM+Vanilla RNN Had. Att.+Transformer     3           8           8   -0.004275          1.000000
#                   GRU                                                      LSTM+Vanilla RNN Had. Att.+Transformer Had. Att.     3           8           8   -0.004361          1.000000
#                   GRU                                                                LSTM+Transformer+Transformer Had. Att.     3           8           8   -0.004314          1.000000
#                   GRU                                                              Vanilla RNN+GRU Had. Att.+LSTM Had. Att.     3           8           8   -0.004576          1.000000
#                   GRU                                                       Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.     3           8           8   -0.004057          1.000000
#                   GRU                                                                 Vanilla RNN+GRU Had. Att.+Transformer     3           8           8   -0.004009          1.000000
#                   GRU                                                       Vanilla RNN+GRU Had. Att.+Transformer Had. Att.     3           8           8   -0.004096          1.000000
#                   GRU                                                      Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.     3           8           8   -0.004095          1.000000
#                   GRU                                                                Vanilla RNN+LSTM Had. Att.+Transformer     3           8           8   -0.004047          1.000000
#                   GRU                                                      Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     3           8           8   -0.004134          1.000000
#                   GRU                                                         Vanilla RNN+Vanilla RNN Had. Att.+Transformer     3           8           8   -0.003529          1.000000
#                   GRU                                               Vanilla RNN+Vanilla RNN Had. Att.+Transformer Had. Att.     3           8           8   -0.003615          1.000000
#                   GRU                                                         Vanilla RNN+Transformer+Transformer Had. Att.     3           8           8   -0.003568          1.000000
#                   GRU                                                    GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.     3           8           8   -0.006646          1.000000
#                   GRU                                                              GRU Had. Att.+LSTM Had. Att.+Transformer     3           8           8   -0.006598          1.000000
#                   GRU                                                    GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     3           8           8   -0.006685          1.000000
#                   GRU                                                       GRU Had. Att.+Vanilla RNN Had. Att.+Transformer     3           8           8   -0.006080          1.000000
#                   GRU                                             GRU Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     3           8           8   -0.006166          1.000000
#                   GRU                                                       GRU Had. Att.+Transformer+Transformer Had. Att.     3           8           8   -0.006119          1.000000
#                   GRU                                                      LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     3           8           8   -0.006118          1.000000
#                   GRU                                            LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     3           8           8   -0.006204          1.000000
#                   GRU                                                      LSTM Had. Att.+Transformer+Transformer Had. Att.     3           8           8   -0.006157          1.000000
#                   GRU                                               Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     3           8           8   -0.005638          1.000000
#                   GRU                                                         LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.     4           8           8   -0.003850          1.000000
#                   GRU                                                  LSTM+Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.     4           8           8   -0.003461          1.000000
#                   GRU                                                            LSTM+Vanilla RNN+GRU Had. Att.+Transformer     4           8           8   -0.003425          1.000000
#                   GRU                                                  LSTM+Vanilla RNN+GRU Had. Att.+Transformer Had. Att.     4           8           8   -0.003490          1.000000
#                   GRU                                                 LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.     4           8           8   -0.003489          1.000000
#                   GRU                                                           LSTM+Vanilla RNN+LSTM Had. Att.+Transformer     4           8           8   -0.003454          1.000000
#                   GRU                                                 LSTM+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     4           8           8   -0.003519          1.000000
#                   GRU                                                    LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer     4           8           8   -0.003065          1.000000
#                   GRU                                          LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer Had. Att.     4           8           8   -0.003130          1.000000
#                   GRU                                                    LSTM+Vanilla RNN+Transformer+Transformer Had. Att.     4           8           8   -0.003094          1.000000
#                   GRU                                               LSTM+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.     4           8           8   -0.005403          1.000000
#                   GRU                                                         LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer     4           8           8   -0.005367          1.000000
#                   GRU                                               LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     4           8           8   -0.005432          1.000000
#                   GRU                                                  LSTM+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer     4           8           8   -0.004978          1.000000
#                   GRU                                        LSTM+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           8           8   -0.005043          1.000000
#                   GRU                                                  LSTM+GRU Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.005008          1.000000
#                   GRU                                                 LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     4           8           8   -0.005007          1.000000
#                   GRU                                       LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           8           8   -0.005072          1.000000
#                   GRU                                                 LSTM+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.005036          1.000000
#                   GRU                                          LSTM+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.004647          1.000000
#                   GRU                                        Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.     4           8           8   -0.004843          1.000000
#                   GRU                                                  Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer     4           8           8   -0.004808          1.000000
#                   GRU                                        Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     4           8           8   -0.004873          1.000000
#                   GRU                                           Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer     4           8           8   -0.004419          1.000000
#                   GRU                                 Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           8           8   -0.004484          1.000000
#                   GRU                                           Vanilla RNN+GRU Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.004448          1.000000
#                   GRU                                          Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     4           8           8   -0.004447          1.000000
#                   GRU                                Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           8           8   -0.004512          1.000000
#                   GRU                                          Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.004477          1.000000
#                   GRU                                   Vanilla RNN+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.004088          1.000000
#                   GRU                                        GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     4           8           8   -0.006360          1.000000
#                   GRU                              GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           8           8   -0.006426          1.000000
#                   GRU                                        GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.006390          1.000000
#                   GRU                                 GRU Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.006001          1.000000
#                   GRU                                LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           8           8   -0.006029          1.000000
#                   GRU                                   LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.     5           8           8   -0.004209          1.000000
#                   GRU                                             LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer     5           8           8   -0.004181          1.000000
#                   GRU                                   LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     5           8           8   -0.004233          1.000000
#                   GRU                                      LSTM+Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer     5           8           8   -0.003870          1.000000
#                   GRU                            LSTM+Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           8           8   -0.003922          1.000000
#                   GRU                                      LSTM+Vanilla RNN+GRU Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.003893          1.000000
#                   GRU                                     LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     5           8           8   -0.003892          1.000000
#                   GRU                           LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           8           8   -0.003944          1.000000
#                   GRU                                     LSTM+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.003916          1.000000
#                   GRU                              LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.003605          1.000000
#                   GRU                                   LSTM+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     5           8           8   -0.005423          1.000000
#                   GRU                         LSTM+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           8           8   -0.005475          1.000000
#                   GRU                                   LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.005447          1.000000
#                   GRU                            LSTM+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.005135          1.000000
#                   GRU                           LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.005158          1.000000
#                   GRU                            Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     5           8           8   -0.004975          1.000000
#                   GRU                  Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           8           8   -0.005027          1.000000
#                   GRU                            Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.004999          1.000000
#                   GRU                     Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.004688          1.000000
#                   GRU                    Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.004711          1.000000
#                   GRU                  GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           8           8   -0.006241          1.000000
#                   GRU                       LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     6           8           8   -0.004425          1.000000
#                   GRU             LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     6           8           8   -0.004468          1.000000
#                   GRU                       LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     6           8           8   -0.004445          1.000000
#                   GRU                LSTM+Vanilla RNN+GRU Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           8           8   -0.004185          1.000000
#                   GRU               LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           8           8   -0.004204          1.000000
#                   GRU             LSTM+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           8           8   -0.005480          1.000000
#                   GRU      Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           8           8   -0.005107          1.000000
#                   GRU LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     7           8           8   -0.004616          1.000000
#         GRU Had. Att.                                                                                                   GRU     1           1           8    0.007089          0.222222
#         GRU Had. Att.                                                                                                  LSTM     1           1           8    0.005416          0.222222
#         GRU Had. Att.                                                                                           Vanilla RNN     1           1           8    0.007653          0.222222
#         GRU Had. Att.                                                                                 Vanilla RNN Had. Att.     1           1           8    0.001442          0.222222
#         GRU Had. Att.                                                                                           Transformer     1           1           8    0.001585          0.222222
#         GRU Had. Att.                                                                                 Transformer Had. Att.     1           1           8    0.001325          0.222222
#         GRU Had. Att.                                                                                        LSTM Had. Att.     1           7           8   -0.000114          0.888889
#         GRU Had. Att.                                                                                              GRU+LSTM     2           1           8    0.006252          0.222222
#         GRU Had. Att.                                                                                       GRU+Vanilla RNN     2           1           8    0.007371          0.222222
#         GRU Had. Att.                                                                                    GRU+LSTM Had. Att.     2           1           8    0.003488          0.222222
#         GRU Had. Att.                                                                             GRU+Vanilla RNN Had. Att.     2           1           8    0.004266          0.222222
#         GRU Had. Att.                                                                                       GRU+Transformer     2           1           8    0.004337          0.222222
#         GRU Had. Att.                                                                             GRU+Transformer Had. Att.     2           1           8    0.004207          0.222222
#         GRU Had. Att.                                                                                      LSTM+Vanilla RNN     2           1           8    0.006535          0.222222
#         GRU Had. Att.                                                                                   LSTM+LSTM Had. Att.     2           1           8    0.002651          0.222222
#         GRU Had. Att.                                                                            LSTM+Vanilla RNN Had. Att.     2           1           8    0.003429          0.222222
#         GRU Had. Att.                                                                                      LSTM+Transformer     2           1           8    0.003500          0.222222
#         GRU Had. Att.                                                                            LSTM+Transformer Had. Att.     2           1           8    0.003370          0.222222
#         GRU Had. Att.                                                                            Vanilla RNN+LSTM Had. Att.     2           1           8    0.003770          0.222222
#         GRU Had. Att.                                                                     Vanilla RNN+Vanilla RNN Had. Att.     2           1           8    0.004548          0.222222
#         GRU Had. Att.                                                                               Vanilla RNN+Transformer     2           1           8    0.004619          0.222222
#         GRU Had. Att.                                                                     Vanilla RNN+Transformer Had. Att.     2           1           8    0.004489          0.222222
#         GRU Had. Att.                                                                  LSTM Had. Att.+Vanilla RNN Had. Att.     2           1           8    0.000664          0.222222
#         GRU Had. Att.                                                                            LSTM Had. Att.+Transformer     2           1           8    0.000735          0.222222
#         GRU Had. Att.                                                                     Vanilla RNN Had. Att.+Transformer     2           1           8    0.001514          0.222222
#         GRU Had. Att.                                                           Vanilla RNN Had. Att.+Transformer Had. Att.     2           1           8    0.001383          0.222222
#         GRU Had. Att.                                                                     Transformer+Transformer Had. Att.     2           1           8    0.001455          0.222222
#         GRU Had. Att.                                                                  LSTM Had. Att.+Transformer Had. Att.     2           2           8    0.000605          0.333333
#         GRU Had. Att.                                                                                  GRU+LSTM+Vanilla RNN     3           1           8    0.006719          0.222222
#         GRU Had. Att.                                                                               GRU+LSTM+LSTM Had. Att.     3           1           8    0.004130          0.222222
#         GRU Had. Att.                                                                        GRU+LSTM+Vanilla RNN Had. Att.     3           1           8    0.004649          0.222222
#         GRU Had. Att.                                                                                  GRU+LSTM+Transformer     3           1           8    0.004696          0.222222
#         GRU Had. Att.                                                                        GRU+LSTM+Transformer Had. Att.     3           1           8    0.004610          0.222222
#         GRU Had. Att.                                                                        GRU+Vanilla RNN+LSTM Had. Att.     3           1           8    0.004876          0.222222
#         GRU Had. Att.                                                                 GRU+Vanilla RNN+Vanilla RNN Had. Att.     3           1           8    0.005395          0.222222
#         GRU Had. Att.                                                                           GRU+Vanilla RNN+Transformer     3           1           8    0.005442          0.222222
#         GRU Had. Att.                                                                 GRU+Vanilla RNN+Transformer Had. Att.     3           1           8    0.005356          0.222222
#         GRU Had. Att.                                                              GRU+LSTM Had. Att.+Vanilla RNN Had. Att.     3           1           8    0.002806          0.222222
#         GRU Had. Att.                                                                        GRU+LSTM Had. Att.+Transformer     3           1           8    0.002853          0.222222
#         GRU Had. Att.                                                              GRU+LSTM Had. Att.+Transformer Had. Att.     3           1           8    0.002767          0.222222
#         GRU Had. Att.                                                                 GRU+Vanilla RNN Had. Att.+Transformer     3           1           8    0.003372          0.222222
#         GRU Had. Att.                                                       GRU+Vanilla RNN Had. Att.+Transformer Had. Att.     3           1           8    0.003285          0.222222
#         GRU Had. Att.                                                                 GRU+Transformer+Transformer Had. Att.     3           1           8    0.003333          0.222222
#         GRU Had. Att.                                                                       LSTM+Vanilla RNN+LSTM Had. Att.     3           1           8    0.004318          0.222222
#         GRU Had. Att.                                                                LSTM+Vanilla RNN+Vanilla RNN Had. Att.     3           1           8    0.004837          0.222222
#         GRU Had. Att.                                                                          LSTM+Vanilla RNN+Transformer     3           1           8    0.004885          0.222222
#         GRU Had. Att.                                                                LSTM+Vanilla RNN+Transformer Had. Att.     3           1           8    0.004798          0.222222
#         GRU Had. Att.                                                             LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.     3           1           8    0.002248          0.222222
#         GRU Had. Att.                                                                       LSTM+LSTM Had. Att.+Transformer     3           1           8    0.002296          0.222222
#         GRU Had. Att.                                                             LSTM+LSTM Had. Att.+Transformer Had. Att.     3           1           8    0.002209          0.222222
#         GRU Had. Att.                                                                LSTM+Vanilla RNN Had. Att.+Transformer     3           1           8    0.002814          0.222222
#         GRU Had. Att.                                                      LSTM+Vanilla RNN Had. Att.+Transformer Had. Att.     3           1           8    0.002728          0.222222
#         GRU Had. Att.                                                                LSTM+Transformer+Transformer Had. Att.     3           1           8    0.002775          0.222222
#         GRU Had. Att.                                                      Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.     3           1           8    0.002994          0.222222
#         GRU Had. Att.                                                                Vanilla RNN+LSTM Had. Att.+Transformer     3           1           8    0.003041          0.222222
#         GRU Had. Att.                                                      Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     3           1           8    0.002955          0.222222
#         GRU Had. Att.                                                         Vanilla RNN+Vanilla RNN Had. Att.+Transformer     3           1           8    0.003560          0.222222
#         GRU Had. Att.                                               Vanilla RNN+Vanilla RNN Had. Att.+Transformer Had. Att.     3           1           8    0.003473          0.222222
#         GRU Had. Att.                                                         Vanilla RNN+Transformer+Transformer Had. Att.     3           1           8    0.003521          0.222222
#         GRU Had. Att.                                                      LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     3           1           8    0.000971          0.222222
#         GRU Had. Att.                                            LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     3           1           8    0.000884          0.222222
#         GRU Had. Att.                                                      LSTM Had. Att.+Transformer+Transformer Had. Att.     3           1           8    0.000932          0.222222
#         GRU Had. Att.                                               Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     3           1           8    0.001451          0.222222
#         GRU Had. Att.                                                                   GRU+LSTM+Vanilla RNN+LSTM Had. Att.     4           1           8    0.005011          0.222222
#         GRU Had. Att.                                                            GRU+LSTM+Vanilla RNN+Vanilla RNN Had. Att.     4           1           8    0.005400          0.222222
#         GRU Had. Att.                                                                      GRU+LSTM+Vanilla RNN+Transformer     4           1           8    0.005436          0.222222
#         GRU Had. Att.                                                            GRU+LSTM+Vanilla RNN+Transformer Had. Att.     4           1           8    0.005371          0.222222
#         GRU Had. Att.                                                         GRU+LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.     4           1           8    0.003458          0.222222
#         GRU Had. Att.                                                                   GRU+LSTM+LSTM Had. Att.+Transformer     4           1           8    0.003494          0.222222
#         GRU Had. Att.                                                         GRU+LSTM+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.003429          0.222222
#         GRU Had. Att.                                                            GRU+LSTM+Vanilla RNN Had. Att.+Transformer     4           1           8    0.003883          0.222222
#         GRU Had. Att.                                                  GRU+LSTM+Vanilla RNN Had. Att.+Transformer Had. Att.     4           1           8    0.003818          0.222222
#         GRU Had. Att.                                                            GRU+LSTM+Transformer+Transformer Had. Att.     4           1           8    0.003853          0.222222
#         GRU Had. Att.                                                  GRU+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.     4           1           8    0.004018          0.222222
#         GRU Had. Att.                                                            GRU+Vanilla RNN+LSTM Had. Att.+Transformer     4           1           8    0.004053          0.222222
#         GRU Had. Att.                                                  GRU+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.003988          0.222222
#         GRU Had. Att.                                                     GRU+Vanilla RNN+Vanilla RNN Had. Att.+Transformer     4           1           8    0.004442          0.222222
#         GRU Had. Att.                                           GRU+Vanilla RNN+Vanilla RNN Had. Att.+Transformer Had. Att.     4           1           8    0.004377          0.222222
#         GRU Had. Att.                                                     GRU+Vanilla RNN+Transformer+Transformer Had. Att.     4           1           8    0.004413          0.222222
#         GRU Had. Att.                                                  GRU+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     4           1           8    0.002501          0.222222
#         GRU Had. Att.                                        GRU+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           1           8    0.002435          0.222222
#         GRU Had. Att.                                                  GRU+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.002471          0.222222
#         GRU Had. Att.                                           GRU+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.002860          0.222222
#         GRU Had. Att.                                                 LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.     4           1           8    0.003599          0.222222
#         GRU Had. Att.                                                           LSTM+Vanilla RNN+LSTM Had. Att.+Transformer     4           1           8    0.003635          0.222222
#         GRU Had. Att.                                                 LSTM+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.003570          0.222222
#         GRU Had. Att.                                                    LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer     4           1           8    0.004024          0.222222
#         GRU Had. Att.                                          LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer Had. Att.     4           1           8    0.003959          0.222222
#         GRU Had. Att.                                                    LSTM+Vanilla RNN+Transformer+Transformer Had. Att.     4           1           8    0.003995          0.222222
#         GRU Had. Att.                                                 LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     4           1           8    0.002082          0.222222
#         GRU Had. Att.                                       LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           1           8    0.002017          0.222222
#         GRU Had. Att.                                                 LSTM+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.002053          0.222222
#         GRU Had. Att.                                          LSTM+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.002442          0.222222
#         GRU Had. Att.                                          Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     4           1           8    0.002642          0.222222
#         GRU Had. Att.                                Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     4           1           8    0.002577          0.222222
#         GRU Had. Att.                                          Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.002612          0.222222
#         GRU Had. Att.                                   Vanilla RNN+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.003001          0.222222
#         GRU Had. Att.                                LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.001059          0.222222
#         GRU Had. Att.                                             GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.     5           1           8    0.004297          0.222222
#         GRU Had. Att.                                                       GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Transformer     5           1           8    0.004326          0.222222
#         GRU Had. Att.                                             GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     5           1           8    0.004274          0.222222
#         GRU Had. Att.                                                GRU+LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer     5           1           8    0.004637          0.222222
#         GRU Had. Att.                                      GRU+LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer Had. Att.     5           1           8    0.004585          0.222222
#         GRU Had. Att.                                                GRU+LSTM+Vanilla RNN+Transformer+Transformer Had. Att.     5           1           8    0.004613          0.222222
#         GRU Had. Att.                                             GRU+LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     5           1           8    0.003084          0.222222
#         GRU Had. Att.                                   GRU+LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           1           8    0.003032          0.222222
#         GRU Had. Att.                                             GRU+LSTM+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.003060          0.222222
#         GRU Had. Att.                                      GRU+LSTM+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.003371          0.222222
#         GRU Had. Att.                                      GRU+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     5           1           8    0.003531          0.222222
#         GRU Had. Att.                            GRU+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           1           8    0.003479          0.222222
#         GRU Had. Att.                                      GRU+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.003508          0.222222
#         GRU Had. Att.                               GRU+Vanilla RNN+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.003819          0.222222
#         GRU Had. Att.                            GRU+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.002265          0.222222
#         GRU Had. Att.                                     LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     5           1           8    0.003197          0.222222
#         GRU Had. Att.                           LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     5           1           8    0.003144          0.222222
#         GRU Had. Att.                                     LSTM+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.003173          0.222222
#         GRU Had. Att.                              LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.003484          0.222222
#         GRU Had. Att.                           LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.001931          0.222222
#         GRU Had. Att.                    Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.002378          0.222222
#         GRU Had. Att.                                 GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer     6           1           8    0.003845          0.222222
#         GRU Had. Att.                       GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer Had. Att.     6           1           8    0.003802          0.222222
#         GRU Had. Att.                                 GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.003826          0.222222
#         GRU Had. Att.                          GRU+LSTM+Vanilla RNN+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.004085          0.222222
#         GRU Had. Att.                       GRU+LSTM+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.002790          0.222222
#         GRU Had. Att.                GRU+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.003163          0.222222
#         GRU Had. Att.               LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.002885          0.222222
#         GRU Had. Att.           GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Vanilla RNN Had. Att.+Transformer+Transformer Had. Att.     7           1           8    0.003485          0.222222
#                  LSTM                                                                                                   GRU     1           1           8    0.001673          0.222222
#                  LSTM                                                                                           Vanilla RNN     1           1           8    0.002238          0.222222
#                  LSTM                                                                                         GRU Had. Att.     1           8           8   -0.005416          1.000000
#                  LSTM                                                                                        LSTM Had. Att.     1           8           8   -0.005530          1.000000
#                  LSTM                                                                                 Vanilla RNN Had. Att.     1           8           8   -0.003973          1.000000
# ...
# Vanilla RNN Had. Att.                                                              GRU+LSTM Had. Att.+Transformer Had. Att.     3           1           8    0.001324          0.222222
# Vanilla RNN Had. Att.                                                                 GRU+Transformer+Transformer Had. Att.     3           1           8    0.001890          0.222222
# Vanilla RNN Had. Att.                                                                        LSTM+Vanilla RNN+GRU Had. Att.     3           1           8    0.002914          0.222222
# Vanilla RNN Had. Att.                                                                       LSTM+Vanilla RNN+LSTM Had. Att.     3           1           8    0.002876          0.222222
# Vanilla RNN Had. Att.                                                                          LSTM+Vanilla RNN+Transformer     3           1           8    0.003442          0.222222
# Vanilla RNN Had. Att.                                                                LSTM+Vanilla RNN+Transformer Had. Att.     3           1           8    0.003356          0.222222
# Vanilla RNN Had. Att.                                                              LSTM+GRU Had. Att.+Transformer Had. Att.     3           1           8    0.000804          0.222222
# Vanilla RNN Had. Att.                                                             LSTM+LSTM Had. Att.+Transformer Had. Att.     3           1           8    0.000766          0.222222
# Vanilla RNN Had. Att.                                                                LSTM+Transformer+Transformer Had. Att.     3           1           8    0.001333          0.222222
# Vanilla RNN Had. Att.                                                              Vanilla RNN+GRU Had. Att.+LSTM Had. Att.     3           1           8    0.001071          0.222222
# Vanilla RNN Had. Att.                                                                 Vanilla RNN+GRU Had. Att.+Transformer     3           1           8    0.001637          0.222222
# Vanilla RNN Had. Att.                                                       Vanilla RNN+GRU Had. Att.+Transformer Had. Att.     3           1           8    0.001550          0.222222
# Vanilla RNN Had. Att.                                                                Vanilla RNN+LSTM Had. Att.+Transformer     3           1           8    0.001599          0.222222
# Vanilla RNN Had. Att.                                                      Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     3           1           8    0.001512          0.222222
# Vanilla RNN Had. Att.                                                         Vanilla RNN+Transformer+Transformer Had. Att.     3           1           8    0.002079          0.222222
# Vanilla RNN Had. Att.                                                                     LSTM+GRU Had. Att.+LSTM Had. Att.     3           2           8    0.000325          0.333333
# Vanilla RNN Had. Att.                                                                        LSTM+GRU Had. Att.+Transformer     3           2           8    0.000891          0.333333
# Vanilla RNN Had. Att.                                                                       LSTM+LSTM Had. Att.+Transformer     3           2           8    0.000853          0.333333
# Vanilla RNN Had. Att.                                                              GRU Had. Att.+LSTM Had. Att.+Transformer     3           7           8   -0.000952          0.888889
# Vanilla RNN Had. Att.                                                       GRU Had. Att.+Transformer+Transformer Had. Att.     3           7           8   -0.000473          0.888889
# Vanilla RNN Had. Att.                                                      LSTM Had. Att.+Transformer+Transformer Had. Att.     3           7           8   -0.000511          0.888889
# Vanilla RNN Had. Att.                                                    GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     3           8           8   -0.001039          1.000000
# Vanilla RNN Had. Att.                                                                    GRU+LSTM+Vanilla RNN+GRU Had. Att.     4           1           8    0.003597          0.222222
# Vanilla RNN Had. Att.                                                                   GRU+LSTM+Vanilla RNN+LSTM Had. Att.     4           1           8    0.003569          0.222222
# Vanilla RNN Had. Att.                                                                      GRU+LSTM+Vanilla RNN+Transformer     4           1           8    0.003993          0.222222
# Vanilla RNN Had. Att.                                                            GRU+LSTM+Vanilla RNN+Transformer Had. Att.     4           1           8    0.003928          0.222222
# Vanilla RNN Had. Att.                                                                 GRU+LSTM+GRU Had. Att.+LSTM Had. Att.     4           1           8    0.001655          0.222222
# Vanilla RNN Had. Att.                                                                    GRU+LSTM+GRU Had. Att.+Transformer     4           1           8    0.002080          0.222222
# Vanilla RNN Had. Att.                                                          GRU+LSTM+GRU Had. Att.+Transformer Had. Att.     4           1           8    0.002015          0.222222
# Vanilla RNN Had. Att.                                                                   GRU+LSTM+LSTM Had. Att.+Transformer     4           1           8    0.002052          0.222222
# Vanilla RNN Had. Att.                                                         GRU+LSTM+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.001986          0.222222
# Vanilla RNN Had. Att.                                                            GRU+LSTM+Transformer+Transformer Had. Att.     4           1           8    0.002411          0.222222
# Vanilla RNN Had. Att.                                                          GRU+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.     4           1           8    0.002215          0.222222
# Vanilla RNN Had. Att.                                                             GRU+Vanilla RNN+GRU Had. Att.+Transformer     4           1           8    0.002639          0.222222
# Vanilla RNN Had. Att.                                                   GRU+Vanilla RNN+GRU Had. Att.+Transformer Had. Att.     4           1           8    0.002574          0.222222
# Vanilla RNN Had. Att.                                                            GRU+Vanilla RNN+LSTM Had. Att.+Transformer     4           1           8    0.002611          0.222222
# Vanilla RNN Had. Att.                                                  GRU+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.002546          0.222222
# Vanilla RNN Had. Att.                                                     GRU+Vanilla RNN+Transformer+Transformer Had. Att.     4           1           8    0.002971          0.222222
# Vanilla RNN Had. Att.                                                          GRU+GRU Had. Att.+LSTM Had. Att.+Transformer     4           1           8    0.000698          0.222222
# Vanilla RNN Had. Att.                                                GRU+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.000633          0.222222
# Vanilla RNN Had. Att.                                                   GRU+GRU Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.001057          0.222222
# Vanilla RNN Had. Att.                                                  GRU+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.001029          0.222222
# Vanilla RNN Had. Att.                                                         LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.     4           1           8    0.001797          0.222222
# Vanilla RNN Had. Att.                                                            LSTM+Vanilla RNN+GRU Had. Att.+Transformer     4           1           8    0.002221          0.222222
# Vanilla RNN Had. Att.                                                  LSTM+Vanilla RNN+GRU Had. Att.+Transformer Had. Att.     4           1           8    0.002156          0.222222
# Vanilla RNN Had. Att.                                                           LSTM+Vanilla RNN+LSTM Had. Att.+Transformer     4           1           8    0.002193          0.222222
# Vanilla RNN Had. Att.                                                 LSTM+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.002128          0.222222
# Vanilla RNN Had. Att.                                                    LSTM+Vanilla RNN+Transformer+Transformer Had. Att.     4           1           8    0.002552          0.222222
# Vanilla RNN Had. Att.                                                  Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer     4           1           8    0.000839          0.222222
# Vanilla RNN Had. Att.                                        Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     4           1           8    0.000774          0.222222
# Vanilla RNN Had. Att.                                           Vanilla RNN+GRU Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.001198          0.222222
# Vanilla RNN Had. Att.                                          Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           1           8    0.001170          0.222222
# Vanilla RNN Had. Att.                                                  LSTM+GRU Had. Att.+Transformer+Transformer Had. Att.     4           2           8    0.000639          0.333333
# Vanilla RNN Had. Att.                                                 LSTM+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           2           8    0.000610          0.333333
# Vanilla RNN Had. Att.                                                         LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer     4           3           8    0.000279          0.444444
# Vanilla RNN Had. Att.                                               LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     4           4           8    0.000214          0.555556
# Vanilla RNN Had. Att.                                        GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     4           7           8   -0.000743          0.888889
# Vanilla RNN Had. Att.                                                     GRU+LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.     5           1           8    0.002566          0.222222
# Vanilla RNN Had. Att.                                                        GRU+LSTM+Vanilla RNN+GRU Had. Att.+Transformer     5           1           8    0.002906          0.222222
# Vanilla RNN Had. Att.                                              GRU+LSTM+Vanilla RNN+GRU Had. Att.+Transformer Had. Att.     5           1           8    0.002854          0.222222
# Vanilla RNN Had. Att.                                                       GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Transformer     5           1           8    0.002883          0.222222
# Vanilla RNN Had. Att.                                             GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Transformer Had. Att.     5           1           8    0.002831          0.222222
# Vanilla RNN Had. Att.                                                GRU+LSTM+Vanilla RNN+Transformer+Transformer Had. Att.     5           1           8    0.003171          0.222222
# Vanilla RNN Had. Att.                                                     GRU+LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer     5           1           8    0.001353          0.222222
# Vanilla RNN Had. Att.                                           GRU+LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     5           1           8    0.001301          0.222222
# Vanilla RNN Had. Att.                                              GRU+LSTM+GRU Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.001640          0.222222
# Vanilla RNN Had. Att.                                             GRU+LSTM+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.001618          0.222222
# Vanilla RNN Had. Att.                                              GRU+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer     5           1           8    0.001800          0.222222
# Vanilla RNN Had. Att.                                    GRU+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     5           1           8    0.001748          0.222222
# Vanilla RNN Had. Att.                                       GRU+Vanilla RNN+GRU Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.002088          0.222222
# Vanilla RNN Had. Att.                                      GRU+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.002065          0.222222
# Vanilla RNN Had. Att.                                             LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer     5           1           8    0.001466          0.222222
# Vanilla RNN Had. Att.                                   LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     5           1           8    0.001414          0.222222
# Vanilla RNN Had. Att.                                      LSTM+Vanilla RNN+GRU Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.001753          0.222222
# Vanilla RNN Had. Att.                                     LSTM+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.001731          0.222222
# Vanilla RNN Had. Att.                            Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           1           8    0.000647          0.222222
# Vanilla RNN Had. Att.                                    GRU+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           2           8    0.000535          0.333333
# Vanilla RNN Had. Att.                                   LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     5           4           8    0.000200          0.555556
# Vanilla RNN Had. Att.                                         GRU+LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer     6           1           8    0.002162          0.222222
# Vanilla RNN Had. Att.                               GRU+LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer Had. Att.     6           1           8    0.002119          0.222222
# Vanilla RNN Had. Att.                                  GRU+LSTM+Vanilla RNN+GRU Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.002402          0.222222
# Vanilla RNN Had. Att.                                 GRU+LSTM+Vanilla RNN+LSTM Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.002383          0.222222
# Vanilla RNN Had. Att.                               GRU+LSTM+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.001108          0.222222
# Vanilla RNN Had. Att.                        GRU+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.001481          0.222222
# Vanilla RNN Had. Att.                       LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     6           1           8    0.001202          0.222222
# Vanilla RNN Had. Att.                   GRU+LSTM+Vanilla RNN+GRU Had. Att.+LSTM Had. Att.+Transformer+Transformer Had. Att.     7           1           8    0.001837          0.222222

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap

pair_df = df_subsets[df_subsets['Size'] == 1]
models = sorted(roc.keys())
count_matrix = np.zeros((len(models), len(models)), dtype=int)

for _, row in pair_df.iterrows():
    i = models.index(row['Model A'])
    j = models.index(row['Subset'])
    count_matrix[i, j] = int(row['Count_mean'])
scaled_matrix = count_matrix / 8.0

mask = np.eye(len(models), dtype=bool)
masked_matrix = np.ma.masked_where(mask, scaled_matrix)


orig = cm.get_cmap('viridis_r', 256)              # viridis reversed
new_colors = orig(np.linspace(0.0, 0.8, 256))     
viridis_cut = ListedColormap(new_colors)

fig, ax = plt.subplots(figsize=(8, 8))
im = ax.imshow(masked_matrix,
               aspect='equal',
               cmap=viridis_cut)   

ax.set_xticks(np.arange(len(models)))
ax.set_yticks(np.arange(len(models)))
ax.set_xticklabels(models, rotation=90, fontsize=12)
ax.set_yticklabels(models, fontsize=12)

for i in range(len(models)):
    for j in range(len(models)):
        if i == j:
            continue
        ax.text(j, i,
                f"{scaled_matrix[i, j]:.3f}",
                ha='center', va='center',
                fontsize=10)

cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cbar.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.savefig('./Figures/permutation_CIRC.pdf')
plt.show()
# Out:
# /tmp/ipykernel_402273/2775023056.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   orig = cm.get_cmap('viridis_r', 256)              # viridis reversed

# %% [markdown]
# # GRU

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
df_gru = pd.read_csv(f"POST-HOC/Results_GRU/metrics_GRU.csv")
df_gru_had = pd.read_csv(f"INTRINSIC/Results_GRU_Had/metrics_GRU_Had.csv")

# Initialize storage for summary
time_steps = df_gru['Time Step'].unique()

gru_means = []
gru_stds = []
gru_had_means = []
gru_had_stds = []

# Storage for Recall and Specificity
gru_recall_means = []
gru_recall_stds = []
gru_specificity_means = []
gru_specificity_stds = []

gru_had_recall_means = []
gru_had_recall_stds = []
gru_had_specificity_means = []
gru_had_specificity_stds = []

# Compute mean and std for each time step
for t in time_steps:
    # For GRU
    gru_roc = df_gru[df_gru['Time Step'] == t]['ROC AUC']
    gru_recall = df_gru[df_gru['Time Step'] == t]['Recall']
    gru_specificity = df_gru[df_gru['Time Step'] == t]['Specificity']
    
    # For GRU + Attention
    gru_had_roc = df_gru_had[df_gru_had['Time Step'] == t]['ROC AUC']
    gru_had_recall = df_gru_had[df_gru_had['Time Step'] == t]['Recall']
    gru_had_specificity = df_gru_had[df_gru_had['Time Step'] == t]['Specificity']
    
    # Store means and stds for GRU
    gru_means.append(gru_roc.mean())
    gru_stds.append(gru_roc.std())
    gru_recall_means.append(gru_recall.mean())
    gru_recall_stds.append(gru_recall.std())
    gru_specificity_means.append(gru_specificity.mean())
    gru_specificity_stds.append(gru_specificity.std())
    
    # Store means and stds for GRU + Attention
    gru_had_means.append(gru_had_roc.mean())
    gru_had_stds.append(gru_had_roc.std())
    gru_had_recall_means.append(gru_had_recall.mean())
    gru_had_recall_stds.append(gru_had_recall.std())
    gru_had_specificity_means.append(gru_had_specificity.mean())
    gru_had_specificity_stds.append(gru_had_specificity.std())

# Convert lists to numpy arrays
gru_means = np.array(gru_means)
gru_stds = np.array(gru_stds)
gru_had_means = np.array(gru_had_means)
gru_had_stds = np.array(gru_had_stds)

gru_recall_means = np.array(gru_recall_means)
gru_recall_stds = np.array(gru_recall_stds)
gru_specificity_means = np.array(gru_specificity_means)
gru_specificity_stds = np.array(gru_specificity_stds)

gru_had_recall_means = np.array(gru_had_recall_means)
gru_had_recall_stds = np.array(gru_had_recall_stds)
gru_had_specificity_means = np.array(gru_had_specificity_means)
gru_had_specificity_stds = np.array(gru_had_specificity_stds)

# Calculate average and mean std over all time steps for ROC AUC, Recall, Specificity
average_gru_roc_auc = np.mean(gru_means)
mean_gru_roc_std = np.mean(gru_stds)

average_gru_had_roc_auc = np.mean(gru_had_means)
mean_gru_had_roc_std = np.mean(gru_had_stds)

average_gru_recall = np.mean(gru_recall_means)
mean_gru_recall_std = np.mean(gru_recall_stds)

average_gru_specificity = np.mean(gru_specificity_means)
mean_gru_specificity_std = np.mean(gru_specificity_stds)

average_gru_had_recall = np.mean(gru_had_recall_means)
mean_gru_had_recall_std = np.mean(gru_had_recall_stds)

average_gru_had_specificity = np.mean(gru_had_specificity_means)
mean_gru_had_specificity_std = np.mean(gru_had_specificity_stds)

# %% [markdown]
# # LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
df_lstm = pd.read_csv(f"POST-HOC/Results_LSTM/metrics_LSTM.csv")
df_lstm_had = pd.read_csv(f"INTRINSIC/Results_LSTM_Had/metrics_LSTM_Had.csv")

# Initialize storage for summary
time_steps = df_lstm['Time Step'].unique()

lstm_means = []
lstm_stds = []
lstm_had_means = []
lstm_had_stds = []

# Storage for Recall and Specificity
lstm_recall_means = []
lstm_recall_stds = []
lstm_specificity_means = []
lstm_specificity_stds = []

lstm_had_recall_means = []
lstm_had_recall_stds = []
lstm_had_specificity_means = []
lstm_had_specificity_stds = []

# Compute mean and std for each time step
for t in time_steps:
    # For LSTM
    lstm_roc = df_lstm[df_lstm['Time Step'] == t]['ROC AUC']
    lstm_recall = df_lstm[df_lstm['Time Step'] == t]['Recall']
    lstm_specificity = df_lstm[df_lstm['Time Step'] == t]['Specificity']
    
    # For LSTM + Attention
    lstm_had_roc = df_lstm_had[df_lstm_had['Time Step'] == t]['ROC AUC']
    lstm_had_recall = df_lstm_had[df_lstm_had['Time Step'] == t]['Recall']
    lstm_had_specificity = df_lstm_had[df_lstm_had['Time Step'] == t]['Specificity']
    
    # Store means and stds for LSTM
    lstm_means.append(lstm_roc.mean())
    lstm_stds.append(lstm_roc.std())
    lstm_recall_means.append(lstm_recall.mean())
    lstm_recall_stds.append(lstm_recall.std())
    lstm_specificity_means.append(lstm_specificity.mean())
    lstm_specificity_stds.append(lstm_specificity.std())
    
    # Store means and stds for LSTM + Attention
    lstm_had_means.append(lstm_had_roc.mean())
    lstm_had_stds.append(lstm_had_roc.std())
    lstm_had_recall_means.append(lstm_had_recall.mean())
    lstm_had_recall_stds.append(lstm_had_recall.std())
    lstm_had_specificity_means.append(lstm_had_specificity.mean())
    lstm_had_specificity_stds.append(lstm_had_specificity.std())

# Convert lists to numpy arrays
lstm_means = np.array(lstm_means)
lstm_stds = np.array(lstm_stds)
lstm_had_means = np.array(lstm_had_means)
lstm_had_stds = np.array(lstm_had_stds)

lstm_recall_means = np.array(lstm_recall_means)
lstm_recall_stds = np.array(lstm_recall_stds)
lstm_specificity_means = np.array(lstm_specificity_means)
lstm_specificity_stds = np.array(lstm_specificity_stds)

lstm_had_recall_means = np.array(lstm_had_recall_means)
lstm_had_recall_stds = np.array(lstm_had_recall_stds)
lstm_had_specificity_means = np.array(lstm_had_specificity_means)
lstm_had_specificity_stds = np.array(lstm_had_specificity_stds)

# Calculate average and mean std over all time steps for ROC AUC, Recall, Specificity
average_lstm_roc_auc = np.mean(lstm_means)
mean_lstm_roc_std = np.mean(lstm_stds)

average_lstm_had_roc_auc = np.mean(lstm_had_means)
mean_lstm_had_roc_std = np.mean(lstm_had_stds)

average_lstm_recall = np.mean(lstm_recall_means)
mean_lstm_recall_std = np.mean(lstm_recall_stds)

average_lstm_specificity = np.mean(lstm_specificity_means)
mean_lstm_specificity_std = np.mean(lstm_specificity_stds)

average_lstm_had_recall = np.mean(lstm_had_recall_means)
mean_lstm_had_recall_std = np.mean(lstm_had_recall_stds)

average_lstm_had_specificity = np.mean(lstm_had_specificity_means)
mean_lstm_had_specificity_std = np.mean(lstm_had_specificity_stds)

# %% [markdown]
# # Vanilla

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
df_vanilla = pd.read_csv(f"POST-HOC/Results_Vanilla/metrics_Vanilla.csv")
df_vanilla_had = pd.read_csv(f"INTRINSIC/Results_Vanilla_Had/metrics_Vanilla_Had.csv")

# Initialize storage for summary
time_steps = df_vanilla['Time Step'].unique()

vanilla_means = []
vanilla_stds = []
vanilla_had_means = []
vanilla_had_stds = []

# Storage for Recall and Specificity
vanilla_recall_means = []
vanilla_recall_stds = []
vanilla_specificity_means = []
vanilla_specificity_stds = []

vanilla_had_recall_means = []
vanilla_had_recall_stds = []
vanilla_had_specificity_means = []
vanilla_had_specificity_stds = []

# Compute mean and std for each time step
for t in time_steps:
    # For Vanilla GRU
    vanilla_roc = df_vanilla[df_vanilla['Time Step'] == t]['ROC AUC']
    vanilla_recall = df_vanilla[df_vanilla['Time Step'] == t]['Recall']
    vanilla_specificity = df_vanilla[df_vanilla['Time Step'] == t]['Specificity']
    
    # For Vanilla GRU + Attention
    vanilla_had_roc = df_vanilla_had[df_vanilla_had['Time Step'] == t]['ROC AUC']
    vanilla_had_recall = df_vanilla_had[df_vanilla_had['Time Step'] == t]['Recall']
    vanilla_had_specificity = df_vanilla_had[df_vanilla_had['Time Step'] == t]['Specificity']
    
    # Store means and stds for Vanilla GRU
    vanilla_means.append(vanilla_roc.mean())
    vanilla_stds.append(vanilla_roc.std())
    vanilla_recall_means.append(vanilla_recall.mean())
    vanilla_recall_stds.append(vanilla_recall.std())
    vanilla_specificity_means.append(vanilla_specificity.mean())
    vanilla_specificity_stds.append(vanilla_specificity.std())
    
    # Store means and stds for Vanilla GRU + Attention
    vanilla_had_means.append(vanilla_had_roc.mean())
    vanilla_had_stds.append(vanilla_had_roc.std())
    vanilla_had_recall_means.append(vanilla_had_recall.mean())
    vanilla_had_recall_stds.append(vanilla_had_recall.std())
    vanilla_had_specificity_means.append(vanilla_had_specificity.mean())
    vanilla_had_specificity_stds.append(vanilla_had_specificity.std())

# Convert lists to numpy arrays
vanilla_means = np.array(vanilla_means)
vanilla_stds = np.array(vanilla_stds)
vanilla_had_means = np.array(vanilla_had_means)
vanilla_had_stds = np.array(vanilla_had_stds)

vanilla_recall_means = np.array(vanilla_recall_means)
vanilla_recall_stds = np.array(vanilla_recall_stds)
vanilla_specificity_means = np.array(vanilla_specificity_means)
vanilla_specificity_stds = np.array(vanilla_specificity_stds)

vanilla_had_recall_means = np.array(vanilla_had_recall_means)
vanilla_had_recall_stds = np.array(vanilla_had_recall_stds)
vanilla_had_specificity_means = np.array(vanilla_had_specificity_means)
vanilla_had_specificity_stds = np.array(vanilla_had_specificity_stds)

# Calculate average and mean std over all time steps for ROC AUC, Recall, Specificity
average_vanilla_roc_auc = np.mean(vanilla_means)
mean_vanilla_roc_std = np.mean(vanilla_stds)

average_vanilla_had_roc_auc = np.mean(vanilla_had_means)
mean_vanilla_had_roc_std = np.mean(vanilla_had_stds)

average_vanilla_recall = np.mean(vanilla_recall_means)
mean_vanilla_recall_std = np.mean(vanilla_recall_stds)

average_vanilla_specificity = np.mean(vanilla_specificity_means)
mean_vanilla_specificity_std = np.mean(vanilla_specificity_stds)

average_vanilla_had_recall = np.mean(vanilla_had_recall_means)
mean_vanilla_had_recall_std = np.mean(vanilla_had_recall_stds)

average_vanilla_had_specificity = np.mean(vanilla_had_specificity_means)
mean_vanilla_had_specificity_std = np.mean(vanilla_had_specificity_stds)

# %% [markdown]
# ## Transformer

# %%
import pandas as pd
import numpy as np

df_trans = pd.read_csv("POST-HOC/Results_transformer/metrics_transformer.csv")
df_trans_had = pd.read_csv("INTRINSIC/Results_transformer_Had/metrics_transformer_Had.csv")

time_steps = df_trans['Time Step'].unique()

trans_means = []
trans_stds = []
trans_had_means = []
trans_had_stds = []

trans_recall_means = []
trans_recall_stds = []
trans_specificity_means = []
trans_specificity_stds = []

trans_had_recall_means = []
trans_had_recall_stds = []
trans_had_specificity_means = []
trans_had_specificity_stds = []

for t in time_steps:
    # For Transformer
    trans_roc = df_trans[df_trans['Time Step'] == t]['ROC AUC']
    trans_recall = df_trans[df_trans['Time Step'] == t]['Recall']
    trans_specificity = df_trans[df_trans['Time Step'] == t]['Specificity']

    # For Transformer + Attention (Hadamard)
    trans_had_roc = df_trans_had[df_trans_had['Time Step'] == t]['ROC AUC']
    trans_had_recall = df_trans_had[df_trans_had['Time Step'] == t]['Recall']
    trans_had_specificity = df_trans_had[df_trans_had['Time Step'] == t]['Specificity']

    # Store means and stds for Transformer
    trans_means.append(trans_roc.mean())
    trans_stds.append(trans_roc.std())
    trans_recall_means.append(trans_recall.mean())
    trans_recall_stds.append(trans_recall.std())
    trans_specificity_means.append(trans_specificity.mean())
    trans_specificity_stds.append(trans_specificity.std())

    # Store means and stds for Transformer + Attention
    trans_had_means.append(trans_had_roc.mean())
    trans_had_stds.append(trans_had_roc.std())
    trans_had_recall_means.append(trans_had_recall.mean())
    trans_had_recall_stds.append(trans_had_recall.std())
    trans_had_specificity_means.append(trans_had_specificity.mean())
    trans_had_specificity_stds.append(trans_had_specificity.std())

# Convert lists to numpy arrays
trans_means = np.array(trans_means)
trans_stds = np.array(trans_stds)
trans_had_means = np.array(trans_had_means)
trans_had_stds = np.array(trans_had_stds)

trans_recall_means = np.array(trans_recall_means)
trans_recall_stds = np.array(trans_recall_stds)
trans_specificity_means = np.array(trans_specificity_means)
trans_specificity_stds = np.array(trans_specificity_stds)

trans_had_recall_means = np.array(trans_had_recall_means)
trans_had_recall_stds = np.array(trans_had_recall_stds)
trans_had_specificity_means = np.array(trans_had_specificity_means)
trans_had_specificity_stds = np.array(trans_had_specificity_stds)

# Calculate overall averages and mean stds across all time steps
average_trans_roc_auc = np.mean(trans_means)
mean_trans_roc_std = np.mean(trans_stds)

average_trans_had_roc_auc = np.mean(trans_had_means)
mean_trans_had_roc_std = np.mean(trans_had_stds)

average_trans_recall = np.mean(trans_recall_means)
mean_trans_recall_std = np.mean(trans_recall_stds)

average_trans_specificity = np.mean(trans_specificity_means)
mean_trans_specificity_std = np.mean(trans_specificity_stds)

average_trans_had_recall = np.mean(trans_had_recall_means)
mean_trans_had_recall_std = np.mean(trans_had_recall_stds)

average_trans_had_specificity = np.mean(trans_had_specificity_means)
mean_trans_had_specificity_std = np.mean(trans_had_specificity_stds)

# %%
def process_df(df, method_name):
    # Group by Time Step and calculate mean and standard deviation
    summary_df = df.groupby('Time Step')['ROC AUC'].agg(['mean', 'std']).reset_index()
    summary_df['Method'] = method_name
    return summary_df

# %%
data = {
    "Model": [
        "GRU", "GRU + Attention",
        "LSTM", "LSTM + Attention",
        "Vanilla RNN", "Vanilla RNN + Attention",
        "Transformer", "Transformer + Attention"
    ],
    "ROC AUC": [
        average_gru_roc_auc, average_gru_had_roc_auc,
        average_lstm_roc_auc, average_lstm_had_roc_auc,
        average_vanilla_roc_auc, average_vanilla_had_roc_auc,
        average_trans_roc_auc, average_trans_had_roc_auc
    ],
    "Recall": [
        average_gru_recall, average_gru_had_recall,
        average_lstm_recall, average_lstm_had_recall,
        average_vanilla_recall, average_vanilla_had_recall,
        average_trans_recall, average_trans_had_recall
    ],
    "Specificity": [
        average_gru_specificity, average_gru_had_specificity,
        average_lstm_specificity, average_lstm_had_specificity,
        average_vanilla_specificity, average_vanilla_had_specificity,
        average_trans_specificity, average_trans_had_specificity
    ],
    "ROC AUC STD": [
        mean_gru_roc_std, mean_gru_had_roc_std,
        mean_lstm_roc_std, mean_lstm_had_roc_std,
        mean_vanilla_roc_std, mean_vanilla_had_roc_std,
        mean_trans_roc_std, mean_trans_had_roc_std
    ],
    "Recall STD": [
        mean_gru_recall_std, mean_gru_had_recall_std,
        mean_lstm_recall_std, mean_lstm_had_recall_std,
        mean_vanilla_recall_std, mean_vanilla_had_recall_std,
        mean_trans_recall_std, mean_trans_had_recall_std
    ],
    "Specificity STD": [
        mean_gru_specificity_std, mean_gru_had_specificity_std,
        mean_lstm_specificity_std, mean_lstm_had_specificity_std,
        mean_vanilla_specificity_std, mean_vanilla_had_specificity_std,
        mean_trans_specificity_std, mean_trans_had_specificity_std
    ],
}

data['ROC AUC ± STD'] = [
    f"{mu:.4f} ± {sigma:.4f}"
    for mu, sigma in zip(data['ROC AUC'], data['ROC AUC STD'])
]
data['Recall ± STD'] = [
    f"{mu:.4f} ± {sigma:.4f}"
    for mu, sigma in zip(data['Recall'], data['Recall STD'])
]
data['Specificity ± STD'] = [
    f"{mu:.4f} ± {sigma:.4f}"
    for mu, sigma in zip(data['Specificity'], data['Specificity STD'])
]

df = pd.DataFrame(data)
df = df.drop(columns=[
    "ROC AUC", "Recall", "Specificity",
    "ROC AUC STD", "Recall STD", "Specificity STD"
])

print(df.to_string(index=False))
# Out:
#                   Model   ROC AUC ± STD    Recall ± STD Specificity ± STD
#                     GRU 0.9898 ± 0.0031 0.9653 ± 0.0113   0.9387 ± 0.0217
#         GRU + Attention 0.9969 ± 0.0020 0.9823 ± 0.0088   0.9745 ± 0.0093
#                    LSTM 0.9915 ± 0.0015 0.9668 ± 0.0096   0.9513 ± 0.0189
#        LSTM + Attention 0.9970 ± 0.0016 0.9854 ± 0.0103   0.9693 ± 0.0178
#             Vanilla RNN 0.9893 ± 0.0033 0.9557 ± 0.0136   0.9478 ± 0.0223
# Vanilla RNN + Attention 0.9955 ± 0.0020 0.9785 ± 0.0124   0.9654 ± 0.0143
#             Transformer 0.9953 ± 0.0021 0.9749 ± 0.0096   0.9645 ± 0.0092
# Transformer + Attention 0.9956 ± 0.0024 0.9736 ± 0.0097   0.9790 ± 0.0070

# %%
def process_df(df, method_name):
    # Group by Time Step and calculate mean and standard deviation
    summary_df = df.groupby('Time Step')['ROC AUC'].agg(['mean', 'std']).reset_index()
    summary_df['Method'] = method_name
    return summary_df

# %% [markdown]
# # ROC AUC

# %%
import seaborn as sns
df_gru           = pd.read_csv("POST-HOC/Results_GRU/metrics_GRU.csv")
df_lstm          = pd.read_csv("POST-HOC/Results_LSTM/metrics_LSTM.csv")
df_vanilla       = pd.read_csv("POST-HOC/Results_Vanilla/metrics_Vanilla.csv")
df_gru_had       = pd.read_csv("INTRINSIC/Results_GRU_Had/metrics_GRU_Had.csv")
df_lstm_had      = pd.read_csv("INTRINSIC/Results_LSTM_Had/metrics_LSTM_Had.csv")
df_vanilla_had   = pd.read_csv("INTRINSIC/Results_Vanilla_Had/metrics_Vanilla_Had.csv")
df_trans         = pd.read_csv("POST-HOC/Results_transformer/metrics_transformer.csv")
df_trans_had     = pd.read_csv("INTRINSIC/Results_transformer_Had/metrics_transformer_Had.csv")

methods = [
    'GRU', 'LSTM', 'Vanilla RNN',
    'GRU Had. Att.', 'LSTM Had. Att.', 'Vanilla RNN Had. Att.',
    'Transformer', 'Transformer Had. Att.'
]
n_time_steps = [str(i) for i in range(1, 9)]

def process_df(df, method_name):
    summary = df.groupby('Time Step')['ROC AUC'].agg(['mean', 'std']).reset_index()
    summary['Method'] = method_name
    return summary

gru_df          = process_df(df_gru,         'GRU')
lstm_df         = process_df(df_lstm,        'LSTM')
vanilla_df      = process_df(df_vanilla,     'Vanilla RNN')
gru_had_df      = process_df(df_gru_had,     'GRU Had. Att.')
lstm_had_df     = process_df(df_lstm_had,    'LSTM Had. Att.')
vanilla_had_df  = process_df(df_vanilla_had, 'Vanilla RNN Had. Att.')
trans_df        = process_df(df_trans,       'Transformer')
trans_had_df    = process_df(df_trans_had,   'Transformer Had. Att.')

all_data = pd.concat([
    gru_df, lstm_df, vanilla_df,
    gru_had_df, lstm_had_df, vanilla_had_df,
    trans_df, trans_had_df
], ignore_index=True)

# ——————————————————————————————————————————————
# PLOT
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(28, 5))

colors  = sns.color_palette('tab10',    len(methods))
markers = ['o', 's', '^', 'D', 'v', 'p', 'X', '*']
width      = 0.12
shift_right = 0.05
ax.xaxis.grid(False)
for idx, method in enumerate(methods):
    md = all_data[all_data['Method'] == method]
    x   = np.arange(len(n_time_steps)) + idx * width - (len(methods)*width/2) + shift_right
    y   = md['mean'].values
    yerr= md['std'].values
    ax.errorbar(
        x, y, yerr=yerr,
        label=method,
        marker=markers[idx],
        color=colors[idx],
        linestyle='',
        markersize=10,
        capsize=5,
        elinewidth=2,
        capthick=2
    )

ax.set_xticks(np.arange(len(n_time_steps)))
ax.set_xticklabels(n_time_steps, fontsize=25)
ax.set_ylim(0.95, 1.0)
ax.tick_params(axis='y', labelsize=25)
plt.xlim(-0.5, len(n_time_steps)-0.5)

for xc in range(1, len(n_time_steps)):
    ax.axvline(x=xc-0.5, color='grey', linestyle='--', alpha=1.0)

for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.0)

plt.tight_layout(pad=1)

ax.legend(
    ncol=len(methods),
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    fontsize=25,           
    frameon=False,
    handlelength=1.0,      
    handletextpad=0.2,     
    columnspacing=2.0,   
    labelspacing=0.1      
)

plt.savefig("./Figures/ROC_AUC_models.pdf",
            bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# # Sensitivity

# %%
import seaborn as sns
df_gru           = pd.read_csv("POST-HOC/Results_GRU/metrics_GRU.csv")
df_lstm          = pd.read_csv("POST-HOC/Results_LSTM/metrics_LSTM.csv")
df_vanilla       = pd.read_csv("POST-HOC/Results_Vanilla/metrics_Vanilla.csv")
df_gru_had       = pd.read_csv("INTRINSIC/Results_GRU_Had/metrics_GRU_Had.csv")
df_lstm_had      = pd.read_csv("INTRINSIC/Results_LSTM_Had/metrics_LSTM_Had.csv")
df_vanilla_had   = pd.read_csv("INTRINSIC/Results_Vanilla_Had/metrics_Vanilla_Had.csv")
df_trans         = pd.read_csv("POST-HOC/Results_transformer/metrics_transformer.csv")
df_trans_had     = pd.read_csv("INTRINSIC/Results_transformer_Had/metrics_transformer_Had.csv")

methods = [
    'GRU', 'LSTM', 'Vanilla RNN',
    'GRU Had. Att.', 'LSTM Had. Att.', 'Vanilla RNN Had. Att.',
    'Transformer', 'Transformer Had. Att.'
]
n_time_steps = [str(i) for i in range(1, 9)]

def process_df(df, method_name):
    summary = df.groupby('Time Step')['Recall'].agg(['mean', 'std']).reset_index()
    summary['Method'] = method_name
    return summary

gru_df          = process_df(df_gru,         'GRU')
lstm_df         = process_df(df_lstm,        'LSTM')
vanilla_df      = process_df(df_vanilla,     'Vanilla RNN')
gru_had_df      = process_df(df_gru_had,     'GRU Had. Att.')
lstm_had_df     = process_df(df_lstm_had,    'LSTM Had. Att.')
vanilla_had_df  = process_df(df_vanilla_had, 'Vanilla RNN Had. Att.')
trans_df        = process_df(df_trans,       'Transformer')
trans_had_df    = process_df(df_trans_had,   'Transformer Had. Att.')

all_data = pd.concat([
    gru_df, lstm_df, vanilla_df,
    gru_had_df, lstm_had_df, vanilla_had_df,
    trans_df, trans_had_df
], ignore_index=True)

# ——————————————————————————————————————————————
# PLOT
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(28, 5))
ax.xaxis.grid(False)
colors  = sns.color_palette('tab10',    len(methods))
markers = ['o', 's', '^', 'D', 'v', 'p', 'X', '*']
width      = 0.12
shift_right = 0.05

for idx, method in enumerate(methods):
    md = all_data[all_data['Method'] == method]
    x   = np.arange(len(n_time_steps)) + idx * width - (len(methods)*width/2) + shift_right
    y   = md['mean'].values
    yerr= md['std'].values
    ax.errorbar(
        x, y, yerr=yerr,
        label=method,
        marker=markers[idx],
        color=colors[idx],
        linestyle='',
        markersize=10,
        capsize=5,
        elinewidth=2,
        capthick=2
    )

ax.set_xticks(np.arange(len(n_time_steps)))
ax.set_xticklabels(n_time_steps, fontsize=25)
ax.set_ylim(0.85, 1.0)
ax.tick_params(axis='y', labelsize=25)
plt.xlim(-0.5, len(n_time_steps)-0.5)

for xc in range(1, len(n_time_steps)):
    ax.axvline(x=xc-0.5, color='grey', linestyle='--', alpha=1.0)

for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.0)

plt.tight_layout(pad=1)

ax.legend(
    ncol=len(methods),
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    fontsize=25,           
    frameon=False,
    handlelength=1.0,      
    handletextpad=0.2,     
    columnspacing=2.0,   
    labelspacing=0.1      
)

plt.savefig("./Figures/Recall_models.pdf",
            bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# # Specificity

# %%
import seaborn as sns
df_gru           = pd.read_csv("POST-HOC/Results_GRU/metrics_GRU.csv")
df_lstm          = pd.read_csv("POST-HOC/Results_LSTM/metrics_LSTM.csv")
df_vanilla       = pd.read_csv("POST-HOC/Results_Vanilla/metrics_Vanilla.csv")
df_gru_had       = pd.read_csv("INTRINSIC/Results_GRU_Had/metrics_GRU_Had.csv")
df_lstm_had      = pd.read_csv("INTRINSIC/Results_LSTM_Had/metrics_LSTM_Had.csv")
df_vanilla_had   = pd.read_csv("INTRINSIC/Results_Vanilla_Had/metrics_Vanilla_Had.csv")
df_trans         = pd.read_csv("POST-HOC/Results_transformer/metrics_transformer.csv")
df_trans_had     = pd.read_csv("INTRINSIC/Results_transformer_Had/metrics_transformer_Had.csv")

methods = [
    'GRU', 'LSTM', 'Vanilla RNN',
    'GRU Had. Att.', 'LSTM Had. Att.', 'Vanilla RNN Had. Att.',
    'Transformer', 'Transformer Had. Att.'
]
n_time_steps = [str(i) for i in range(1, 9)]

def process_df(df, method_name):
    summary = df.groupby('Time Step')['Specificity'].agg(['mean', 'std']).reset_index()
    summary['Method'] = method_name
    return summary

gru_df          = process_df(df_gru,         'GRU')
lstm_df         = process_df(df_lstm,        'LSTM')
vanilla_df      = process_df(df_vanilla,     'Vanilla RNN')
gru_had_df      = process_df(df_gru_had,     'GRU Had. Att.')
lstm_had_df     = process_df(df_lstm_had,    'LSTM Had. Att.')
vanilla_had_df  = process_df(df_vanilla_had, 'Vanilla RNN Had. Att.')
trans_df        = process_df(df_trans,       'Transformer')
trans_had_df    = process_df(df_trans_had,   'Transformer Had. Att.')

all_data = pd.concat([
    gru_df, lstm_df, vanilla_df,
    gru_had_df, lstm_had_df, vanilla_had_df,
    trans_df, trans_had_df
], ignore_index=True)

# ——————————————————————————————————————————————
# PLOT
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(28, 5))
ax.xaxis.grid(False)
colors  = sns.color_palette('tab10',    len(methods))
markers = ['o', 's', '^', 'D', 'v', 'p', 'X', '*']
width      = 0.12
shift_right = 0.05

for idx, method in enumerate(methods):
    md = all_data[all_data['Method'] == method]
    x   = np.arange(len(n_time_steps)) + idx * width - (len(methods)*width/2) + shift_right
    y   = md['mean'].values
    yerr= md['std'].values
    ax.errorbar(
        x, y, yerr=yerr,
        label=method,
        marker=markers[idx],
        color=colors[idx],
        linestyle='',
        markersize=10,
        capsize=5,
        elinewidth=2,
        capthick=2
    )

ax.set_xticks(np.arange(len(n_time_steps)))
ax.set_xticklabels(n_time_steps, fontsize=25)
ax.set_ylim(0.85, 1.0)
ax.tick_params(axis='y', labelsize=25)
plt.xlim(-0.5, len(n_time_steps)-0.5)

for xc in range(1, len(n_time_steps)):
    ax.axvline(x=xc-0.5, color='grey', linestyle='--', alpha=1.0)

for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(1.0)

plt.tight_layout(pad=1)

ax.legend(
    ncol=len(methods),
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    fontsize=25,           
    frameon=False,
    handlelength=1.0,      
    handletextpad=0.2,     
    columnspacing=2.0,   
    labelspacing=0.1      
)

plt.savefig("./Figures/Specificity_models.pdf",
            bbox_inches='tight', pad_inches=0)
plt.show()
